# %%
import matplotlib.pyplot as plt

# %%
x = [2, 3, 5]
y= [1, 3, 4]
plt.plot(x, y, marker="o")

# %%
fig, ax = plt.subplots()

ax.plot(x, y)

# %%
fig

# %%
z = [5, 2, 9]

ax.plot(x, z)
fig

# %%
fig
